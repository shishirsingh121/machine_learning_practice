# %%
import pandas as pd
# from sklearn.model_selection import LogisticRegression

# %%
df=pd.read_csv(r"C:\python code\machine learning\17_l1&l2_regularization\Melbourne_housing_FULL.csv")
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.drop(['Date','CouncilArea','Lattitude','Longtitude','Regionname'],axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# Propertycount        3
# dtype: int64

# %%
clos_to_fill_zero=['Propertycount','Distance','Bathroom','Bedroom2', 'Car']
df[clos_to_fill_zero]=df[clos_to_fill_zero].fillna(0)
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     126.0           NaN
# 1       2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 2       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 3       2.5    3067.0       3.0       2.0  1.0       0.0           NaN
# 4       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
#
#    YearBuilt  Propertycount
# 0        NaN         4019.0
# 1        NaN         4019.0
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# Propertycount        0
# dtype: int64

# %%
df['Landsize']=df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea']=df['BuildingArea'].fillna(df.BuildingArea.mean())
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     126.0      160.2564
# 1       2.5    3067.0       2.0       1.0  1.0     202.0      160.2564
# 2       2.5    3067.0       2.0       1.0  0.0     156.0       79.0000
# 3       2.5    3067.0       3.0       2.0  1.0       0.0      160.2564
# 4       2.5    3067.0       3.0       2.0  0.0     134.0      150.0000
#
#    YearBuilt  Propertycount
# 0        NaN         4019.0
# 1        NaN         4019.0
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             0
# Postcode             1
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize             0
# BuildingArea         0
# YearBuilt        19306
# Propertycount        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# Propertycount    0
# dtype: int64

# %%
df=pd.get_dummies(df,drop_first=True)
df.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       3.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       4.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       2.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  ...  SellerG_buyMyplace  SellerG_hockingstuart  \
# 2           79.0     1900.0  ...               False                  False
# 4          150.0     1900.0  ...               False                  False
# 6          142.0     2014.0  ...               False                  False
# 11         210.0     1910.0  ...               False                  False
# 14         107.0     1890.0  ...               False                  False
#
# ...

# %%
X=df.drop(['Price'],axis=1)
y=df.Price

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
model.score(X_test,y_test)

# %%
from sklearn import linear_model
reg=linear_model()

# %%
reg.lasso(alpha=50,max_iter=100,tol=0.1)
reg,lasso(X_train,y_train)

# %%
df.X
