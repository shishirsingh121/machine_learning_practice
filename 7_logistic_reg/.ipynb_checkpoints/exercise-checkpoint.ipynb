# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\python code\machine learning\7_logistic_reg\HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
ledf=df
ledf.Department=le.fit_transform(ledf.Department)
ledf.salary=le.fit_transform(ledf.salary)
ledf
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
ra=ledf.drop(['last_evaluation','Work_accident','average_montly_hours','time_spend_company'],axis=1)
ra
# Out:
#        satisfaction_level  number_project  left  promotion_last_5years  \
# 0                    0.38               2     1                      0
# 1                    0.80               5     1                      0
# 2                    0.11               7     1                      0
# 3                    0.72               5     1                      0
# 4                    0.37               2     1                      0
# ...                   ...             ...   ...                    ...
# 14994                0.40               2     1                      0
# 14995                0.37               2     1                      0
# 14996                0.37               2     1                      0
# 14997                0.11               6     1                      0
# 14998                0.37               2     1                      0
#
#        Department  salary
# 0               7       1
# 1               7       2
# 2               7       2
# ...

# %%
left=ra[ra.left==0]
ra.shape
# Out:
# (14999, 6)

# %%
retention=ra[ra.left==1]
retention.shape
# Out:
# (3571, 6)

# %%
ra.groupby('left').mean()
# Out:
#       satisfaction_level  number_project  promotion_last_5years  Department  \
# left
# 0               0.666810        3.786664               0.026251    5.819041
# 1               0.440098        3.855503               0.005321    6.035284
#
#         salary
# left
# 0     1.347742
# 1     1.345842

# %%
import matplotlib.pyplot as plt

# %%
X
# Out:
# <BarContainer object of 14999 artists>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)

       
model.predict(X_test)


model.score(X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)
#       3 from sklearn.linear_model import LogisticRegression
#       4 model = LogisticRegression()
#
# NameError: name 'X' is not defined
