# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r"C:\python code\machine learning\6.Training&testing_data\carprices (1).csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
X=df[['Mileage','Age(yrs)']]
y=df['Sell Price($)']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 9     67000         6
# 16    28000         2
# 12    59000         5
# 11    79000         7
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 19    52000         5
# 4     46000         4
# 10    83000         7
# 8     91000         8
# 15    25400         3
# 5     59000         5
# 17    69000         5
# 14    82450         7
# 6     52000         5

# %%
y_train
# Out:
# 9     22000
# 16    35500
# 12    26000
# 11    19500
# 0     18000
# 1     34000
# 2     26100
# 19    28200
# 4     31500
# 10    18700
# 8     12000
# 15    35000
# 5     26750
# 17    19700
# 14    19400
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf= LinearRegression()

# %%
clf.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([35734.3700494 , 24626.7076226 , 25370.81145966, 16003.63020157,
#        14592.0956484 , 29932.41691363, 38017.73476776, 22054.67767026,
#        33663.70792455, 25370.81145966, 28276.9120103 , 26201.1259027 ,
#        18738.54388085, 20809.2060057 , 17077.91499477, 37649.21725115])

# %%
clf.score(X_train , y_train)
# Out:
# 0.9207871590551227
